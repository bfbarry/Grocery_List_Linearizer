# %%
import numpy as np
import pandas as pd

# %%
# an isle list for general category, not location (eg cheese may be in a different isle)
isles = {'frozen foods':['pizza', 'vegetables', 'microwaveables'], 'dairy':['milk', 'yogurt', 'cheese']}

# %% [markdown]
# Store object should have a matrix of isle-item matrix, that connects to a dict?

# %%
class store(object):
    def __init__(self):
        self.store_name = name
        

    def createIsles(self):

# %% [markdown]
# linearizeList function: input is a list, output is a reordered list with corresponding isle id's

# %%
def linearizeList(store):
    reordered_list = {} #where keys are isle, by order 
    
    return reordered_list

# %%
l = [0]

def makeList():
    l = ['Grocery List']
    for i in l:
        if i != 'end':
            l.append(input('Enter an item: '))

    print(l)
    return l
